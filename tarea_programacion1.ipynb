# %% [markdown]
# <a href="https://colab.research.google.com/github/joseydyrueda-code/programacion1/blob/main/tarea_programacion1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarea Programacion

# %% [markdown]
# video 1

# %% [markdown]
# Listas

# %%
# Listas
lista = [29, True, 3.1415, "El numero de Avogadro si que mola" ]
print(lista[0])
# Out:
# 29

# %%
lista = [29, True, 3.1415, "El numero de Avogadro si que mola" ]
print(lista[-1])
# Out:
# El numero de Avogadro si que mola

# %%
lista = [29, True, 3.1415, "El numero de Avogadro si que mola" ]
print(lista[0:-1])
# Out:
# [29, True, 3.1415]

# %%
lista = [29, True, 3.1415, "El numero de Avogadro si que mola" ]
lista[2] = "He cambiado este elemento"
print(lista)
# Out:
# [29, True, 'He cambiado este elemento', 'El numero de Avogadro si que mola']

# %%
lista = [29, True, 3.1415, "El numero de Avogadro si que mola" ]
lista[2] = [1, 2, 3, 4]
print(lista)
# Out:
# [29, True, [1, 2, 3, 4], 'El numero de Avogadro si que mola']

# %%
lista_nueva = [1, 2, 3, 4, 5]
lista_nueva.append(3)
print(lista_nueva)
print(lista_nueva.count(3))
print(lista_nueva.index(4))
print(lista_nueva.remove(3))
# Out:
# [1, 2, 3, 4, 5, 3]
# 2
# 3
# None

# %% [markdown]
# Tuplas

# %%
#Tuplas
tupla = ("¿La tierra es plana?", True, False)
print(tupla)
# Out:
# ('¿La tierra es plana?', True, False)

# %%
tupla = ("¿La tierra es plana?", True, False)
print(tupla[0])
print(tupla[1])
print(tupla[2])
print(tupla.count(True))
print(tupla.index(False))
print((1, ))
# Out:
# ¿La tierra es plana?
# True
# False
# 1
# 2
# (1,)

# %% [markdown]
# conjuntos

# %%
#conjuntos
print(set([1, 2, 3, 4]))
print(set((1, 2, 3, 4)))
print(set("45678.5"))
# Out:
# {1, 2, 3, 4}
# {1, 2, 3, 4}
# {'8', '4', '6', '.', '7', '5'}

# %%
conjunto = set([2, 3, 4])
print(conjunto)

conjunto.add(1)
print(conjunto)

conjunto.remove(1)
print(conjunto)
# Out:
# {2, 3, 4}
# {1, 2, 3, 4}
# {2, 3, 4}

# %%
conjunto_2 = set([5, 3, 5, 6])
conjunto_3 = set([4, 2])
print(conjunto, conjunto_2, conjunto_3)
print(conjunto.intersection(conjunto_2))
print(conjunto_2.issubset(conjunto))
print(conjunto_3.issubset(conjunto))
print(conjunto & conjunto_2)
print(conjunto | conjunto_2)
print(conjunto - conjunto_2)
# Out:
# {2, 3, 4} {3, 5, 6} {2, 4}
# {3}
# False
# True
# {3}
# {2, 3, 4, 5, 6}
# {2, 4}

# %% [markdown]
# Diccionarios

# %%
#diccionarios
diccionario = {1: "uno", 2: "dos"}
diccionario[3] = "tres"
print(diccionario)

dict_lista_tuplas = dict([(1, "uno"), (2, "dos"), (3, "tres")])
print(dict_lista_tuplas)

dict_lista_string = dict(uno= 1, dos =2, tres = 3)
print(dict_lista_string)

dict_tipos = {1: "integer", 2.2: "float", "texto": "string", (1, 2): "tupla"}
print(dict_tipos)

dict_repeticion = {1: "primero", 1: "ultimo"}
print(dict_repeticion)

print(diccionario, diccionario.keys(), diccionario.values(), diccionario.items())
claves = diccionario.values()
print(claves)
diccionario[1] = "one"
print(claves)
diccionario.pop(2)
print(diccionario)
# Out:
# {1: 'uno', 2: 'dos', 3: 'tres'}
# {1: 'uno', 2: 'dos', 3: 'tres'}
# {'uno': 1, 'dos': 2, 'tres': 3}
# {1: 'integer', 2.2: 'float', 'texto': 'string', (1, 2): 'tupla'}
# {1: 'ultimo'}
# {1: 'uno', 2: 'dos', 3: 'tres'} dict_keys([1, 2, 3]) dict_values(['uno', 'dos', 'tres']) dict_items([(1, 'uno'), (2, 'dos'), (3, 'tres')])
# dict_values(['uno', 'dos', 'tres'])
# dict_values(['one', 'dos', 'tres'])
# {1: 'one', 3: 'tres'}

# %% [markdown]
# Ejercicios

# %%
#listas
personajes = ["kakyoin", "joseph", "jotaro"]
personajes.remove("kakyoin")
print(personajes)

personajes.append("polnareff")
print(personajes)

resultado = personajes[1:2]
print(resultado)
# Out:
# ['joseph', 'jotaro']
# ['joseph', 'jotaro', 'polnareff']
# ['jotaro']

# %%
#tuplas
respuesta = ("yes", "yes", "yes")
resultado = (respuesta.count("yes"), respuesta.index("yes"))
print(resultado)
# Out:
# (3, 0)

# %%
#conjuntos
temporada_2 =  set(["joseph", "caesar"])
temporada_3 = set(["jotaro", "joseph", "avdol", "kakyoin", "polnareff"])
resultado = temporada_2 & temporada_3
print(resultado)
# Out:
# {'joseph'}

# %%
#diccionarios
protas = {1: "jonathan", 2: "joseph", 3:"jotaro"}
jojos= {"jonnatan": "phantom blood", "joseph": "battle tendency", "jotaro": "stardust crusaders"}

resultado = jojos[protas[3]]
print(resultado)
# Out:
# stardust crusaders

# %% [markdown]
# video 2

# %%
print(0, "->", bool(0))
print(0.0, "->", bool(0.0))
print("", "->", bool(""))
print(list(), "->", bool(list()))
print(tuple(), "->", bool(tuple()))
print(set()), "->", bool(set())
print(dict()), "->", bool(dict())
print(None, "->", bool(None))
# Out:
# 0 -> False
# 0.0 -> False
#  -> False
# [] -> False
# () -> False
# set()
# {}
# None -> False

# %%
print(9000, "->", bool(9000))
print(3.1415, "->", bool(3.1415))
print("Cadena", "->", bool("Cadena"))
print(list((1, 2)), "->", bool(list((1, 2))))
print(tuple((1, 2)), "->", bool(tuple((1, 2))))
print(set((1, 2)), "->", bool(set((1, 2))))
print(dict([(1,2)]), "->", bool(dict([(1,1)])))
# Out:
# 9000 -> True
# 3.1415 -> True
# Cadena -> True
# [1, 2] -> True
# (1, 2) -> True
# {1, 2} -> True
# {1: 2} -> True

# %%
nota = float(input("introduzca su nota: "))
if nota < 5:
  print("estas suspenso, F")
else:
   print("estas aprobado, ¡enhorabuena!")
# Out:
# introduzca su nota: 8
# estas aprobado, ¡enhorabuena!

# %%
nota = float(input("Introduzca su nota: "))
if 0 <= nota and nota < 5:
  print("Estás suspenso, F")
elif 5 <= nota and nota < 7:
  print("Aprobado")
elif 7 <= nota and nota < 9:
  print("Notable")
elif 9 <= nota and nota <= 10:
  print("Sobresaliente")
else:
  print("Nota fuera de rango")
# Out:
# Introduzca su nota: 2
# Estás suspenso, F

# %%
#bucles
#while
contador = 3
while contador != 0:
  contador = contador - 1
  print("El contenido de contador es", contador)
# Out:
# El contenido de contador es 2
# El contenido de contador es 1
# El contenido de contador es 0

# %%
contador = 3
while contador != 0:
  contador = contador - 2
  print("El contenido de contador es", contador)

  # recomiendo no ejecutarlo, da un resultado enorme (porque falta break)

# %%
contador = 3
while contador > 0:
  contador = contador - 1
  print("El contenido de contador es", contador)
  # al colocar el > se soluciona ese problema
# Out:
# El contenido de contador es 2
# El contenido de contador es 1
# El contenido de contador es 0

# %%
# sentencia for
for iterador in [1, 2, 3]:
  print(iterador)
# Out:
# 1
# 2
# 3

# %%
lista = list((2, 1, 0))
tupla = tuple((2, 1, 0))
conjunto = set((2, 1, 0))
diccionario = dict(((2,"Dos"), (1, "Uno"), (0, "Cero")))

for iterador in lista:
  print(iterador)

for iterador in tupla:
  print(iterador)

for iterador in conjunto:
  print(iterador)

for iterador in diccionario:
  print(iterador)

for iterador in diccionario.values():
  print(iterador)

for iterador in diccionario.items():
  print(iterador)
# Out:
# 2
# 1
# 0
# 2
# 1
# 0
# 0
# 1
# 2
# 2
# 1
# 0
# Dos
# Uno
# Cero
# (2, 'Dos')
# (1, 'Uno')
# (0, 'Cero')

# %%
lista = ["Vamos", "a", "acceder", "a", "esta", "lista", "por", "índices"]

for indice in range(len(lista)):
  print("Indice:", indice,"Elemento:", lista[indice])
# Out:
# Indice: 0 Elemento: Vamos
# Indice: 1 Elemento: a
# Indice: 2 Elemento: acceder
# Indice: 3 Elemento: a
# Indice: 4 Elemento: esta
# Indice: 5 Elemento: lista
# Indice: 6 Elemento: por
# Indice: 7 Elemento: índices

# %%
for numero in range(5):
  print(numero)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for numero in range(5):
  if numero == 3:
    break
  print(numero)
# Out:
# 0
# 1
# 2

# %%
for numero in range(5):
  if numero == 3:
    continue
  print(numero)
# Out:
# 0
# 1
# 2
# 4

# %%
intentos = 3
while intentos > 0:
  if input(">>> Escriba la contraseña:") == "BitBoss":
    print("¡Correcta!")
    break
  intentos = intentos - 1
  print("Contraseña incorrecta")
# Out:
# >>> Escriba la contraseña:jhdjd
# Contraseña incorrecta
# >>> Escriba la contraseña:kjsdus
# Contraseña incorrecta
# >>> Escriba la contraseña:hola
# Contraseña incorrecta

# %%
intentos = 3
while intentos > 0:
  if input(">>> Escriba la contraseña:") == "BitBoss":
    print("¡Correcta!")
    break
  intentos = intentos - 1
  print("Contraseña incorrecta")
else:
  print("Se te acabaron los intentos :(")
# Out:
# >>> Escriba la contraseña:hola
# Contraseña incorrecta
# >>> Escriba la contraseña:hpla
# Contraseña incorrecta
# >>> Escriba la contraseña:hola
# Contraseña incorrecta
# Se te acabaron los intentos :(
