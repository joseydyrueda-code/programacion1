# %% [markdown]
# <a href="https://colab.research.google.com/github/joseydyrueda-code/programacion1/blob/main/tarea_programacion1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarea Programacion

# %% [markdown]
# video 1

# %% [markdown]
# Listas

# %%
# Listas
lista = [29, True, 3.1415, "El numero de Avogadro si que mola" ]
print(lista[0])
# Out:
# 29

# %%
lista = [29, True, 3.1415, "El numero de Avogadro si que mola" ]
print(lista[-1])
# Out:
# El numero de Avogadro si que mola

# %%
lista = [29, True, 3.1415, "El numero de Avogadro si que mola" ]
print(lista[0:-1])
# Out:
# [29, True, 3.1415]

# %%
lista = [29, True, 3.1415, "El numero de Avogadro si que mola" ]
lista[2] = "He cambiado este elemento"
print(lista)
# Out:
# [29, True, 'He cambiado este elemento', 'El numero de Avogadro si que mola']

# %%
lista = [29, True, 3.1415, "El numero de Avogadro si que mola" ]
lista[2] = [1, 2, 3, 4]
print(lista)
# Out:
# [29, True, [1, 2, 3, 4], 'El numero de Avogadro si que mola']

# %%
lista_nueva = [1, 2, 3, 4, 5]
lista_nueva.append(3)
print(lista_nueva)
print(lista_nueva.count(3))
print(lista_nueva.index(4))
print(lista_nueva.remove(3))
# Out:
# [1, 2, 3, 4, 5, 3]
# 2
# 3
# None

# %% [markdown]
# Tuplas

# %%
#Tuplas
tupla = ("¿La tierra es plana?", True, False)
print(tupla)
# Out:
# ('¿La tierra es plana?', True, False)

# %%
tupla = ("¿La tierra es plana?", True, False)
print(tupla[0])
print(tupla[1])
print(tupla[2])
print(tupla.count(True))
print(tupla.index(False))
print((1, ))
# Out:
# ¿La tierra es plana?
# True
# False
# 1
# 2
# (1,)

# %% [markdown]
# conjuntos

# %%
#conjuntos
print(set([1, 2, 3, 4]))
print(set((1, 2, 3, 4)))
print(set("45678.5"))
# Out:
# {1, 2, 3, 4}
# {1, 2, 3, 4}
# {'8', '4', '6', '.', '7', '5'}

# %%
conjunto = set([2, 3, 4])
print(conjunto)

conjunto.add(1)
print(conjunto)

conjunto.remove(1)
print(conjunto)
# Out:
# {2, 3, 4}
# {1, 2, 3, 4}
# {2, 3, 4}

# %%
conjunto_2 = set([5, 3, 5, 6])
conjunto_3 = set([4, 2])
print(conjunto, conjunto_2, conjunto_3)
print(conjunto.intersection(conjunto_2))
print(conjunto_2.issubset(conjunto))
print(conjunto_3.issubset(conjunto))
print(conjunto & conjunto_2)
print(conjunto | conjunto_2)
print(conjunto - conjunto_2)
# Out:
# {2, 3, 4} {3, 5, 6} {2, 4}
# {3}
# False
# True
# {3}
# {2, 3, 4, 5, 6}
# {2, 4}

# %% [markdown]
# Diccionarios

# %%
#diccionarios
diccionario = {1: "uno", 2: "dos"}
diccionario[3] = "tres"
print(diccionario)

dict_lista_tuplas = dict([(1, "uno"), (2, "dos"), (3, "tres")])
print(dict_lista_tuplas)

dict_lista_string = dict(uno= 1, dos =2, tres = 3)
print(dict_lista_string)

dict_tipos = {1: "integer", 2.2: "float", "texto": "string", (1, 2): "tupla"}
print(dict_tipos)

dict_repeticion = {1: "primero", 1: "ultimo"}
print(dict_repeticion)

print(diccionario, diccionario.keys(), diccionario.values(), diccionario.items())
claves = diccionario.values()
print(claves)
diccionario[1] = "one"
print(claves)
diccionario.pop(2)
print(diccionario)
# Out:
# {1: 'uno', 2: 'dos', 3: 'tres'}
# {1: 'uno', 2: 'dos', 3: 'tres'}
# {'uno': 1, 'dos': 2, 'tres': 3}
# {1: 'integer', 2.2: 'float', 'texto': 'string', (1, 2): 'tupla'}
# {1: 'ultimo'}
# {1: 'uno', 2: 'dos', 3: 'tres'} dict_keys([1, 2, 3]) dict_values(['uno', 'dos', 'tres']) dict_items([(1, 'uno'), (2, 'dos'), (3, 'tres')])
# dict_values(['uno', 'dos', 'tres'])
# dict_values(['one', 'dos', 'tres'])
# {1: 'one', 3: 'tres'}

# %% [markdown]
# Ejercicios

# %%
#listas
personajes = ["kakyoin", "joseph", "jotaro"]
personajes.remove("kakyoin")
print(personajes)

personajes.append("polnareff")
print(personajes)

resultado = personajes[1:2]
print(resultado)
# Out:
# ['joseph', 'jotaro']
# ['joseph', 'jotaro', 'polnareff']
# ['jotaro']

# %%
#tuplas
respuesta = ("yes", "yes", "yes")
resultado = (respuesta.count("yes"), respuesta.index("yes"))
print(resultado)
# Out:
# (3, 0)

# %%
#conjuntos
temporada_2 =  set(["joseph", "caesar"])
temporada_3 = set(["jotaro", "joseph", "avdol", "kakyoin", "polnareff"])
resultado = temporada_2 & temporada_3
print(resultado)
# Out:
# {'joseph'}

# %%
#diccionarios
protas = {1: "jonathan", 2: "joseph", 3:"jotaro"}
jojos= {"jonnatan": "phantom blood", "joseph": "battle tendency", "jotaro": "stardust crusaders"}

resultado = jojos[protas[3]]
print(resultado)
# Out:
# stardust crusaders

# %% [markdown]
# video 2

# %%
print(0, "->", bool(0))
print(0.0, "->", bool(0.0))
print("", "->", bool(""))
print(list(), "->", bool(list()))
print(tuple(), "->", bool(tuple()))
print(set()), "->", bool(set())
print(dict()), "->", bool(dict())
print(None, "->", bool(None))
# Out:
# 0 -> False
# 0.0 -> False
#  -> False
# [] -> False
# () -> False
# set()
# {}
# None -> False

# %%
print(9000, "->", bool(9000))
print(3.1415, "->", bool(3.1415))
print("Cadena", "->", bool("Cadena"))
print(list((1, 2)), "->", bool(list((1, 2))))
print(tuple((1, 2)), "->", bool(tuple((1, 2))))
print(set((1, 2)), "->", bool(set((1, 2))))
print(dict([(1,2)]), "->", bool(dict([(1,1)])))
# Out:
# 9000 -> True
# 3.1415 -> True
# Cadena -> True
# [1, 2] -> True
# (1, 2) -> True
# {1, 2} -> True
# {1: 2} -> True

# %%
nota = float(input("introduzca su nota: "))
if nota < 5:
  print("estas suspenso, F")
else:
   print("estas aprobado, ¡enhorabuena!")
# Out:
# introduzca su nota: 8
# estas aprobado, ¡enhorabuena!

# %%
nota = float(input("Introduzca su nota: "))
if 0 <= nota and nota < 5:
  print("Estás suspenso, F")
elif 5 <= nota and nota < 7:
  print("Aprobado")
elif 7 <= nota and nota < 9:
  print("Notable")
elif 9 <= nota and nota <= 10:
  print("Sobresaliente")
else:
  print("Nota fuera de rango")
# Out:
# Introduzca su nota: 2
# Estás suspenso, F

# %%
#bucles
#while
contador = 3
while contador != 0:
  contador = contador - 1
  print("El contenido de contador es", contador)
# Out:
# El contenido de contador es 2
# El contenido de contador es 1
# El contenido de contador es 0

# %%
contador = 3
while contador != 0:
  contador = contador - 2
  print("El contenido de contador es", contador)
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# El contenido de contador es -472779
# El contenido de contador es -472781
# El contenido de contador es -472783
# El contenido de contador es -472785
# El contenido de contador es -472787
# El contenido de contador es -472789
# El contenido de contador es -472791
# El contenido de contador es -472793
# El contenido de contador es -472795
# El contenido de contador es -472797
# El contenido de contador es -472799
# El contenido de contador es -472801
# El contenido de contador es -472803
# El contenido de contador es -472805
# El contenido de contador es -472807
# El contenido de contador es -472809
# El contenido de contador es -472811
# El contenido de contador es -472813
# El contenido de contador es -472815
# El contenido de contador es -472817
# El contenido de contador es -472819
# El contenido de contador es -472821
# El contenido de contador es -472823
# El contenido de contador es -472825
# El contenido de contador es -472827
# El contenido de contador es -472829
# El contenido de contador es -472831
# El contenido de contador es -472833
# El contenido de contador es -472835
# El contenido de contador es -472837
# El contenido de contador es -472839
# El contenido de contador es -472841
# El contenido de contador es -472843
# El contenido de contador es -472845
# El contenido de contador es -472847
# El contenido de contador es -472849
# El contenido de contador es -472851
# El contenido de contador es -472853
# El contenido de contador es -472855
# El contenido de contador es -472857
# El contenido de contador es -472859
# El contenido de contador es -472861
# El contenido de contador es -472863
# El contenido de contador es -472865
# El contenido de contador es -472867
# El contenido de contador es -472869
# El contenido de contador es -472871
# El contenido de contador es -472873
# El contenido de contador es -472875
# El contenido de contador es -472877
# El contenido de contador es -472879
# El contenido de contador es -472881
# El contenido de contador es -472883
# El contenido de contador es -472885
# El contenido de contador es -472887
# El contenido de contador es -472889
# El contenido de contador es -472891
# El contenido de contador es -472893
# El contenido de contador es -472895
# El contenido de contador es -472897
# El contenido de contador es -472899
# El contenido de contador es -472901
# El contenido de contador es -472903
# El contenido de contador es -472905
# El contenido de contador es -472907
# El contenido de contador es -472909
# El contenido de contador es -472911
# El contenido de contador es -472913
# El contenido de contador es -472915
# El contenido de contador es -472917
# El contenido de contador es -472919
# El contenido de contador es -472921
# El contenido de contador es -472923
# El contenido de contador es -472925
# El contenido de contador es -472927
# El contenido de contador es -472929
# El contenido de contador es -472931
# El contenido de contador es -472933
# El contenido de contador es -472935
# El contenido de contador es -472937
# El contenido de contador es -472939
# El contenido de contador es -472941
# El contenido de contador es -472943
# El contenido de contador es -472945
# El contenido de contador es -472947
# El contenido de contador es -472949
# El contenido de contador es -472951
# El contenido de contador es -472953
# El contenido de contador es -472955
# El contenido de contador es -472957
# El contenido de contador es -472959
# El contenido de contador es -472961
# El contenido de contador es -472963
# El contenido de contador es -472965
# El contenido de contador es -472967
# El contenido de contador es -472969
# El contenido de contador es -472971
# El contenido de contador es -472973
# El contenido de contador es -472975
# El contenido de contador es -472977
# El contenido de contador es -472979
# El contenido de contador es -472981
# El contenido de contador es -472983
# El contenido de contador es -472985
# El contenido de contador es -472987
# El contenido de contador es -472989
# El contenido de contador es -472991
# El contenido de contador es -472993
# El contenido de contador es -472995
# El contenido de contador es -472997
# El contenido de contador es -472999
# El contenido de contador es -473001
# El contenido de contador es -473003
# El contenido de contador es -473005
# El contenido de contador es -473007
# El contenido de contador es -473009
# El contenido de contador es -473011
# El contenido de contador es -473013
# El contenido de contador es -473015
# El contenido de contador es -473017
# El contenido de contador es -473019
# El contenido de contador es -473021
# El contenido de contador es -473023
# El contenido de contador es -473025
# El contenido de contador es -473027
# El contenido de contador es -473029
# El contenido de contador es -473031
# El contenido de contador es -473033
# El contenido de contador es -473035
# El contenido de contador es -473037
# El contenido de contador es -473039
# El contenido de contador es -473041
# El contenido de contador es -473043
# El contenido de contador es -473045
# El contenido de contador es -473047
# El contenido de contador es -473049
# El contenido de contador es -473051
# El contenido de contador es -473053
# El contenido de contador es -473055
# El contenido de contador es -473057
# El contenido de contador es -473059
# El contenido de contador es -473061
# El contenido de contador es -473063
# El contenido de contador es -473065
# El contenido de contador es -473067
# El contenido de contador es -473069
# El contenido de contador es -473071
# El contenido de contador es -473073
# El contenido de contador es -473075
# El contenido de contador es -473077
# El contenido de contador es -473079
# El contenido de contador es -473081
# El contenido de contador es -473083
# El contenido de contador es -473085
# El contenido de contador es -473087
# El contenido de contador es -473089
# El contenido de contador es -473091
# El contenido de contador es -473093
# El contenido de contador es -473095
# El contenido de contador es -473097
# El contenido de contador es -473099
# El contenido de contador es -473101
# El contenido de contador es -473103
# El contenido de contador es -473105
# El contenido de contador es -473107
# El contenido de contador es -473109
# El contenido de contador es -473111
# El contenido de contador es -473113
# El contenido de contador es -473115
# El contenido de contador es -473117
# El contenido de contador es -473119
# El contenido de contador es -473121
# El contenido de contador es -473123
# El contenido de contador es -473125
# El contenido de contador es -473127
# El contenido de contador es -473129
# El contenido de contador es -473131
# El contenido de contador es -473133
# El contenido de contador es -473135
# El contenido de contador es -473137
# El contenido de contador es -473139
# El contenido de contador es -473141
# El contenido de contador es -473143
# El contenido de contador es -473145
# El contenido de contador es -473147
# El contenido de contador es -473149
# El contenido de contador es -473151
# El contenido de contador es -473153
# El contenido de contador es -473155
# El contenido de contador es -473157
# El contenido de contador es -473159
# El contenido de contador es -473161
# El contenido de contador es -473163
# El contenido de contador es -473165
# El contenido de contador es -473167
# El contenido de contador es -473169
# El contenido de contador es -473171
# El contenido de contador es -473173
# El contenido de contador es -473175
# El contenido de contador es -473177
# El contenido de contador es -473179
# El contenido de contador es -473181
# El contenido de contador es -473183
# El contenido de contador es -473185
# El contenido de contador es -473187
# El contenido de contador es -473189
# El contenido de contador es -473191
# El contenido de contador es -473193
# El contenido de contador es -473195
# El contenido de contador es -473197
# El contenido de contador es -473199
# El contenido de contador es -473201
# El contenido de contador es -473203
# El contenido de contador es -473205
# El contenido de contador es -473207
# El contenido de contador es -473209
# El contenido de contador es -473211
# El contenido de contador es -473213
# El contenido de contador es -473215
# El contenido de contador es -473217
# El contenido de contador es -473219
# El contenido de contador es -473221
# El contenido de contador es -473223
# El contenido de contador es -473225
# El contenido de contador es -473227
# El contenido de contador es -473229
# El contenido de contador es -473231
# El contenido de contador es -473233
# El contenido de contador es -473235
# El contenido de contador es -473237
# El contenido de contador es -473239
# El contenido de contador es -473241
# El contenido de contador es -473243
# El contenido de contador es -473245
# El contenido de contador es -473247
# El contenido de contador es -473249
# El contenido de contador es -473251
# El contenido de contador es -473253
# El contenido de contador es -473255
# El contenido de contador es -473257
# El contenido de contador es -473259
# El contenido de contador es -473261
# El contenido de contador es -473263
# El contenido de contador es -473265
# El contenido de contador es -473267
# El contenido de contador es -473269
# El contenido de contador es -473271
# El contenido de contador es -473273
# El contenido de contador es -473275
# El contenido de contador es -473277
# El contenido de contador es -473279
# El contenido de contador es -473281
# El contenido de contador es -473283
# El contenido de contador es -473285
# El contenido de contador es -473287
# El contenido de contador es -473289
# El contenido de contador es -473291
# El contenido de contador es -473293
# El contenido de contador es -473295
# El contenido de contador es -473297
# El contenido de contador es -473299
# El contenido de contador es -473301
# El contenido de contador es -473303
# El contenido de contador es -473305
# El contenido de contador es -473307
# El contenido de contador es -473309
# El contenido de contador es -473311
# El contenido de contador es -473313
# El contenido de contador es -473315
# El contenido de contador es -473317
# El contenido de contador es -473319
# El contenido de contador es -473321
# El contenido de contador es -473323
# El contenido de contador es -473325
# El contenido de contador es -473327
# El contenido de contador es -473329
# El contenido de contador es -473331
# El contenido de contador es -473333
# El contenido de contador es -473335
# El contenido de contador es -473337
# El contenido de contador es -473339
# El contenido de contador es -473341
# El contenido de contador es -473343
# El contenido de contador es -473345
# El contenido de contador es -473347
# El contenido de contador es -473349
# El contenido de contador es -473351
# El contenido de contador es -473353
# El contenido de contador es -473355
# El contenido de contador es -473357
# El contenido de contador es -473359
# El contenido de contador es -473361
# El contenido de contador es -473363
# El contenido de contador es -473365
# El contenido de contador es -473367
# El contenido de contador es -473369
# El contenido de contador es -473371
# El contenido de contador es -473373
# El contenido de contador es -473375
# El contenido de contador es -473377
# El contenido de contador es -473379
# El contenido de contador es -473381
# El contenido de contador es -473383
# El contenido de contador es -473385
# El contenido de contador es -473387
# El contenido de contador es -473389
# El contenido de contador es -473391
# El contenido de contador es -473393
# El contenido de contador es -473395
# El contenido de contador es -473397
# El contenido de contador es -473399
# El contenido de contador es -473401
# El contenido de contador es -473403
# El contenido de contador es -473405
# El contenido de contador es -473407
# El contenido de contador es -473409
# El contenido de contador es -473411
# El contenido de contador es -473413
# El contenido de contador es -473415
# El contenido de contador es -473417
# El contenido de contador es -473419
# El contenido de contador es -473421
# El contenido de contador es -473423
# El contenido de contador es -473425
# El contenido de contador es -473427
# El contenido de contador es -473429
# El contenido de contador es -473431
# El contenido de contador es -473433
# El contenido de contador es -473435
# El contenido de contador es -473437
# El contenido de contador es -473439
# El contenido de contador es -473441
# El contenido de contador es -473443
# El contenido de contador es -473445
# El contenido de contador es -473447
# El contenido de contador es -473449
# El contenido de contador es -473451
# El contenido de contador es -473453
# El contenido de contador es -473455
# El contenido de contador es -473457
# El contenido de contador es -473459
# El contenido de contador es -473461
# El contenido de contador es -473463
# El contenido de contador es -473465
# El contenido de contador es -473467
# El contenido de contador es -473469
# El contenido de contador es -473471
# El contenido de contador es -473473
# El contenido de contador es -473475
# El contenido de contador es -473477
# El contenido de contador es -473479
# El contenido de contador es -473481
# El contenido de contador es -473483
# El contenido de contador es -473485
# El contenido de contador es -473487
# El contenido de contador es -473489
# El contenido de contador es -473491
# El contenido de contador es -473493
# El contenido de contador es -473495
# El contenido de contador es -473497
# El contenido de contador es -473499
# El contenido de contador es -473501
# El contenido de contador es -473503
# El contenido de contador es -473505
# El contenido de contador es -473507
# El contenido de contador es -473509
# El contenido de contador es -473511
# El contenido de contador es -473513
# El contenido de contador es -473515
# El contenido de contador es -473517
# El contenido de contador es -473519
# El contenido de contador es -473521
# El contenido de contador es -473523
# El contenido de contador es -473525
# El contenido de contador es -473527
# El contenido de contador es -473529
# El contenido de contador es -473531
# El contenido de contador es -473533
# El contenido de contador es -473535
# El contenido de contador es -473537
# El contenido de contador es -473539
# El contenido de contador es -473541
# El contenido de contador es -473543
# El contenido de contador es -473545
# El contenido de contador es -473547
# El contenido de contador es -473549
# El contenido de contador es -473551
# El contenido de contador es -473553
# El contenido de contador es -473555
# El contenido de contador es -473557
# El contenido de contador es -473559
# El contenido de contador es -473561
# El contenido de contador es -473563
# El contenido de contador es -473565
# El contenido de contador es -473567
# El contenido de contador es -473569
# El contenido de contador es -473571
# El contenido de contador es -473573
# El contenido de contador es -473575
# El contenido de contador es -473577
# El contenido de contador es -473579
# El contenido de contador es -473581
# El contenido de contador es -473583
# El contenido de contador es -473585
# El contenido de contador es -473587
# El contenido de contador es -473589
# El contenido de contador es -473591
# El contenido de contador es -473593
# El contenido de contador es -473595
# El contenido de contador es -473597
# El contenido de contador es -473599
# El contenido de contador es -473601
# El contenido de contador es -473603
# El contenido de contador es -473605
# El contenido de contador es -473607
# El contenido de contador es -473609
# El contenido de contador es -473611
# El contenido de contador es -473613
# El contenido de contador es -473615
# El contenido de contador es -473617
# El contenido de contador es -473619
# El contenido de contador es -473621
# El contenido de contador es -473623
# El contenido de contador es -473625
# El contenido de contador es -473627
# El contenido de contador es -473629
# El contenido de contador es -473631
# El contenido de contador es -473633
# El contenido de contador es -473635
# El contenido de contador es -473637
# El contenido de contador es -473639
# El contenido de contador es -473641
# El contenido de contador es -473643
# El contenido de contador es -473645
# El contenido de contador es -473647
# El contenido de contador es -473649
# El contenido de contador es -473651
# El contenido de contador es -473653
# El contenido de contador es -473655
# El contenido de contador es -473657
# El contenido de contador es -473659
# El contenido de contador es -473661
# El contenido de contador es -473663
# El contenido de contador es -473665
# El contenido de contador es -473667
# El contenido de contador es -473669
# El contenido de contador es -473671
# El contenido de contador es -473673
# El contenido de contador es -473675
# El contenido de contador es -473677
# El contenido de contador es -473679
# El contenido de contador es -473681
# El contenido de contador es -473683
# El contenido de contador es -473685
# El contenido de contador es -473687
# El contenido de contador es -473689
# El contenido de contador es -473691
# El contenido de contador es -473693
# El contenido de contador es -473695
# El contenido de contador es -473697
# El contenido de contador es -473699
# El contenido de contador es -473701
# El contenido de contador es -473703
# El contenido de contador es -473705
# El contenido de contador es -473707
# El contenido de contador es -473709
# El contenido de contador es -473711
# El contenido de contador es -473713
# El contenido de contador es -473715
# El contenido de contador es -473717
# El contenido de contador es -473719
# El contenido de contador es -473721
# El contenido de contador es -473723
# El contenido de contador es -473725
# El contenido de contador es -473727
# El contenido de contador es -473729
# El contenido de contador es -473731
# El contenido de contador es -473733
# El contenido de contador es -473735
# El contenido de contador es -473737
# El contenido de contador es -473739
# El contenido de contador es -473741
# El contenido de contador es -473743
# El contenido de contador es -473745
# El contenido de contador es -473747
# El contenido de contador es -473749
# El contenido de contador es -473751
# El contenido de contador es -473753
# El contenido de contador es -473755
# El contenido de contador es -473757
# El contenido de contador es -473759
# El contenido de contador es -473761
# El contenido de contador es -473763
# El contenido de contador es -473765
# El contenido de contador es -473767
# El contenido de contador es -473769
# El contenido de contador es -473771
# El contenido de contador es -473773
# El contenido de contador es -473775
# El contenido de contador es -473777
# El contenido de contador es -473779
# El contenido de contador es -473781
# El contenido de contador es -473783
# El contenido de contador es -473785
# El contenido de contador es -473787
# El contenido de contador es -473789
# El contenido de contador es -473791
# El contenido de contador es -473793
# El contenido de contador es -473795
# El contenido de contador es -473797
# El contenido de contador es -473799
# El contenido de contador es -473801
# El contenido de contador es -473803
# El contenido de contador es -473805
# El contenido de contador es -473807
# El contenido de contador es -473809
# El contenido de contador es -473811
# El contenido de contador es -473813
# El contenido de contador es -473815
# El contenido de contador es -473817
# El contenido de contador es -473819
# El contenido de contador es -473821
# El contenido de contador es -473823
# El contenido de contador es -473825
# El contenido de contador es -473827
# El contenido de contador es -473829
# El contenido de contador es -473831
# El contenido de contador es -473833
# El contenido de contador es -473835
# El contenido de contador es -473837
# El contenido de contador es -473839
# El contenido de contador es -473841
# El contenido de contador es -473843
# El contenido de contador es -473845
# El contenido de contador es -473847
# El contenido de contador es -473849
# El contenido de contador es -473851
# El contenido de contador es -473853
# El contenido de contador es -473855
# El contenido de contador es -473857
# El contenido de contador es -473859
# El contenido de contador es -473861
# El contenido de contador es -473863
# El contenido de contador es -473865
# El contenido de contador es -473867
# El contenido de contador es -473869
# El contenido de contador es -473871
# El contenido de contador es -473873
# El contenido de contador es -473875
# El contenido de contador es -473877
# El contenido de contador es -473879
# El contenido de contador es -473881
# El contenido de contador es -473883
# El contenido de contador es -473885
# El contenido de contador es -473887
# El contenido de contador es -473889
# El contenido de contador es -473891
# El contenido de contador es -473893
# El contenido de contador es -473895
# El contenido de contador es -473897
# El contenido de contador es -473899
# El contenido de contador es -473901
# El contenido de contador es -473903
# El contenido de contador es -473905
# El contenido de contador es -473907
# El contenido de contador es -473909
# El contenido de contador es -473911
# El contenido de contador es -473913
# El contenido de contador es -473915
# El contenido de contador es -473917
# El contenido de contador es -473919
# El contenido de contador es -473921
# El contenido de contador es -473923
# El contenido de contador es -473925
# El contenido de contador es -473927
# El contenido de contador es -473929
# El contenido de contador es -473931
# El contenido de contador es -473933
# El contenido de contador es -473935
# El contenido de contador es -473937
# El contenido de contador es -473939
# El contenido de contador es -473941
# El contenido de contador es -473943
# El contenido de contador es -473945
# El contenido de contador es -473947
# El contenido de contador es -473949
# El contenido de contador es -473951
# El contenido de contador es -473953
# El contenido de contador es -473955
# El contenido de contador es -473957
# El contenido de contador es -473959
# El contenido de contador es -473961
# El contenido de contador es -473963
# El contenido de contador es -473965
# El contenido de contador es -473967
# El contenido de contador es -473969
# El contenido de contador es -473971
# El contenido de contador es -473973
# El contenido de contador es -473975
# El contenido de contador es -473977
# El contenido de contador es -473979
# El contenido de contador es -473981
# El contenido de contador es -473983
# El contenido de contador es -473985
# El contenido de contador es -473987
# El contenido de contador es -473989
# El contenido de contador es -473991
# El contenido de contador es -473993
# El contenido de contador es -473995
# El contenido de contador es -473997
# El contenido de contador es -473999
# El contenido de contador es -474001
# El contenido de contador es -474003
# El contenido de contador es -474005
# El contenido de contador es -474007
# El contenido de contador es -474009
# El contenido de contador es -474011
# El contenido de contador es -474013
# El contenido de contador es -474015
# El contenido de contador es -474017
# El contenido de contador es -474019
# El contenido de contador es -474021
# El contenido de contador es -474023
# El contenido de contador es -474025
# El contenido de contador es -474027
# El contenido de contador es -474029
# El contenido de contador es -474031
# El contenido de contador es -474033
# El contenido de contador es -474035
# El contenido de contador es -474037
# El contenido de contador es -474039
# El contenido de contador es -474041
# El contenido de contador es -474043
# El contenido de contador es -474045
# El contenido de contador es -474047
# El contenido de contador es -474049
# El contenido de contador es -474051
# El contenido de contador es -474053
# El contenido de contador es -474055
# El contenido de contador es -474057
# El contenido de contador es -474059
# El contenido de contador es -474061
# El contenido de contador es -474063
# El contenido de contador es -474065
# El contenido de contador es -474067
# El contenido de contador es -474069
# El contenido de contador es -474071
# El contenido de contador es -474073
# El contenido de contador es -474075
# El contenido de contador es -474077
# El contenido de contador es -474079
# El contenido de contador es -474081
# El contenido de contador es -474083
# El contenido de contador es -474085
# El contenido de contador es -474087
# El contenido de contador es -474089
# El contenido de contador es -474091
# El contenido de contador es -474093
# El contenido de contador es -474095
# El contenido de contador es -474097
# El contenido de contador es -474099
# El contenido de contador es -474101
# El contenido de contador es -474103
# El contenido de contador es -474105
# El contenido de contador es -474107
# El contenido de contador es -474109
# El contenido de contador es -474111
# El contenido de contador es -474113
# El contenido de contador es -474115
# El contenido de contador es -474117
# El contenido de contador es -474119
# El contenido de contador es -474121
# El contenido de contador es -474123
# El contenido de contador es -474125
# El contenido de contador es -474127
# El contenido de contador es -474129
# El contenido de contador es -474131
# El contenido de contador es -474133
# El contenido de contador es -474135
# El contenido de contador es -474137
# El contenido de contador es -474139
# El contenido de contador es -474141
# El contenido de contador es -474143
# El contenido de contador es -474145
# El contenido de contador es -474147
# El contenido de contador es -474149
# El contenido de contador es -474151
# El contenido de contador es -474153
# El contenido de contador es -474155
# El contenido de contador es -474157
# El contenido de contador es -474159
# El contenido de contador es -474161
# El contenido de contador es -474163
# El contenido de contador es -474165
# El contenido de contador es -474167
# El contenido de contador es -474169
# El contenido de contador es -474171
# El contenido de contador es -474173
# El contenido de contador es -474175
# El contenido de contador es -474177
# El contenido de contador es -474179
# El contenido de contador es -474181
# El contenido de contador es -474183
# El contenido de contador es -474185
# El contenido de contador es -474187
# El contenido de contador es -474189
# El contenido de contador es -474191
# El contenido de contador es -474193
# El contenido de contador es -474195
# El contenido de contador es -474197
# El contenido de contador es -474199
# El contenido de contador es -474201
# El contenido de contador es -474203
# El contenido de contador es -474205
# El contenido de contador es -474207
# El contenido de contador es -474209
# El contenido de contador es -474211
# El contenido de contador es -474213
# El contenido de contador es -474215
# El contenido de contador es -474217
# El contenido de contador es -474219
# El contenido de contador es -474221
# El contenido de contador es -474223
# El contenido de contador es -474225
# El contenido de contador es -474227
# El contenido de contador es -474229
# El contenido de contador es -474231
# El contenido de contador es -474233
# El contenido de contador es -474235
# El contenido de contador es -474237
# El contenido de contador es -474239
# El contenido de contador es -474241
# El contenido de contador es -474243
# El contenido de contador es -474245
# El contenido de contador es -474247
# El contenido de contador es -474249
# El contenido de contador es -474251
# El contenido de contador es -474253
# El contenido de contador es -474255
# El contenido de contador es -474257
# El contenido de contador es -474259
# El contenido de contador es -474261
# El contenido de contador es -474263
# El contenido de contador es -474265
# El contenido de contador es -474267
# El contenido de contador es -474269
# El contenido de contador es -474271
# El contenido de contador es -474273
# El contenido de contador es -474275
# El contenido de contador es -474277
# El contenido de contador es -474279
# El contenido de contador es -474281
# El contenido de contador es -474283
# El contenido de contador es -474285
# El contenido de contador es -474287
# El contenido de contador es -474289
# El contenido de contador es -474291
# El contenido de contador es -474293
# El contenido de contador es -474295
# El contenido de contador es -474297
# El contenido de contador es -474299
# El contenido de contador es -474301
# El contenido de contador es -474303
# El contenido de contador es -474305
# El contenido de contador es -474307
# El contenido de contador es -474309
# El contenido de contador es -474311
# El contenido de contador es -474313
# El contenido de contador es -474315
# El contenido de contador es -474317
# El contenido de contador es -474319
# El contenido de contador es -474321
# El contenido de contador es -474323
# El contenido de contador es -474325
# El contenido de contador es -474327
# El contenido de contador es -474329
# El contenido de contador es -474331
# El contenido de contador es -474333
# El contenido de contador es -474335
# El contenido de contador es -474337
# El contenido de contador es -474339
# El contenido de contador es -474341
# El contenido de contador es -474343
# El contenido de contador es -474345
# El contenido de contador es -474347
# El contenido de contador es -474349
# El contenido de contador es -474351
# El contenido de contador es -474353
# El contenido de contador es -474355
# El contenido de contador es -474357
# El contenido de contador es -474359
# El contenido de contador es -474361
# El contenido de contador es -474363
# El contenido de contador es -474365
# El contenido de contador es -474367
# El contenido de contador es -474369
# El contenido de contador es -474371
# El contenido de contador es -474373
# El contenido de contador es -474375
# El contenido de contador es -474377
# El contenido de contador es -474379
# El contenido de contador es -474381
# El contenido de contador es -474383
# El contenido de contador es -474385
# El contenido de contador es -474387
# El contenido de contador es -474389
# El contenido de contador es -474391
# El contenido de contador es -474393
# El contenido de contador es -474395
# El contenido de contador es -474397
# El contenido de contador es -474399
# El contenido de contador es -474401
# El contenido de contador es -474403
# El contenido de contador es -474405
# El contenido de contador es -474407
# El contenido de contador es -474409
# El contenido de contador es -474411
# El contenido de contador es -474413
# El contenido de contador es -474415
# El contenido de contador es -474417
# El contenido de contador es -474419
# El contenido de contador es -474421
# El contenido de contador es -474423
# El contenido de contador es -474425
# El contenido de contador es -474427
# El contenido de contador es -474429
# El contenido de contador es -474431
# El contenido de contador es -474433
# El contenido de contador es -474435
# El contenido de contador es -474437
# El contenido de contador es -474439
# El contenido de contador es -474441
# El contenido de contador es -474443
# El contenido de contador es -474445
# El contenido de contador es -474447
# El contenido de contador es -474449
# El contenido de contador es -474451
# El contenido de contador es -474453
# El contenido de contador es -474455
# El contenido de contador es -474457
# El contenido de contador es -474459
# El contenido de contador es -474461
# El contenido de contador es -474463
# El contenido de contador es -474465
# El contenido de contador es -474467
# El contenido de contador es -474469
# El contenido de contador es -474471
# El contenido de contador es -474473
# El contenido de contador es -474475
# El contenido de contador es -474477
# El contenido de contador es -474479
# El contenido de contador es -474481
# El contenido de contador es -474483
# El contenido de contador es -474485
# El contenido de contador es -474487
# El contenido de contador es -474489
# El contenido de contador es -474491
# El contenido de contador es -474493
# El contenido de contador es -474495
# El contenido de contador es -474497
# El contenido de contador es -474499
# El contenido de contador es -474501
# El contenido de contador es -474503
# El contenido de contador es -474505
# El contenido de contador es -474507
# El contenido de contador es -474509
# El contenido de contador es -474511
# El contenido de contador es -474513
# El contenido de contador es -474515
# El contenido de contador es -474517
# El contenido de contador es -474519
# El contenido de contador es -474521
# El contenido de contador es -474523
# El contenido de contador es -474525
# El contenido de contador es -474527
# El contenido de contador es -474529
# El contenido de contador es -474531
# El contenido de contador es -474533
# El contenido de contador es -474535
# El contenido de contador es -474537
# El contenido de contador es -474539
# El contenido de contador es -474541
# El contenido de contador es -474543
# El contenido de contador es -474545
# El contenido de contador es -474547
# El contenido de contador es -474549
# El contenido de contador es -474551
# El contenido de contador es -474553
# El contenido de contador es -474555
# El contenido de contador es -474557
# El contenido de contador es -474559
# El contenido de contador es -474561
# El contenido de contador es -474563
# El contenido de contador es -474565
# El contenido de contador es -474567
# El contenido de contador es -474569
# El contenido de contador es -474571
# El contenido de contador es -474573
# El contenido de contador es -474575
# El contenido de contador es -474577
# El contenido de contador es -474579
# El contenido de contador es -474581
# El contenido de contador es -474583
# El contenido de contador es -474585
# El contenido de contador es -474587
# El contenido de contador es -474589
# El contenido de contador es -474591
# El contenido de contador es -474593
# El contenido de contador es -474595
# El contenido de contador es -474597
# El contenido de contador es -474599
# El contenido de contador es -474601
# El contenido de contador es -474603
# El contenido de contador es -474605
# El contenido de contador es -474607
# El contenido de contador es -474609
# El contenido de contador es -474611
# El contenido de contador es -474613
# El contenido de contador es -474615
# El contenido de contador es -474617
# El contenido de contador es -474619
# El contenido de contador es -474621
# El contenido de contador es -474623
# El contenido de contador es -474625
# El contenido de contador es -474627
# El contenido de contador es -474629
# El contenido de contador es -474631
# El contenido de contador es -474633
# El contenido de contador es -474635
# El contenido de contador es -474637
# El contenido de contador es -474639
# El contenido de contador es -474641
# El contenido de contador es -474643
# El contenido de contador es -474645
# El contenido de contador es -474647
# El contenido de contador es -474649
# El contenido de contador es -474651
# El contenido de contador es -474653
# El contenido de contador es -474655
# El contenido de contador es -474657
# El contenido de contador es -474659
# El contenido de contador es -474661
# El contenido de contador es -474663
# El contenido de contador es -474665
# El contenido de contador es -474667
# El contenido de contador es -474669
# El contenido de contador es -474671
# El contenido de contador es -474673
# El contenido de contador es -474675
# El contenido de contador es -474677
# El contenido de contador es -474679
# El contenido de contador es -474681
# El contenido de contador es -474683
# El contenido de contador es -474685
# El contenido de contador es -474687
# El contenido de contador es -474689
# El contenido de contador es -474691
# El contenido de contador es -474693
# El contenido de contador es -474695
# El contenido de contador es -474697
# El contenido de contador es -474699
# El contenido de contador es -474701
# El contenido de contador es -474703
# El contenido de contador es -474705
# El contenido de contador es -474707
# El contenido de contador es -474709
# El contenido de contador es -474711
# El contenido de contador es -474713
# El contenido de contador es -474715
# El contenido de contador es -474717
# El contenido de contador es -474719
# El contenido de contador es -474721
# El contenido de contador es -474723
# El contenido de contador es -474725
# El contenido de contador es -474727
# El contenido de contador es -474729
# El contenido de contador es -474731
# El contenido de contador es -474733
# El contenido de contador es -474735
# El contenido de contador es -474737
# El contenido de contador es -474739
# El contenido de contador es -474741
# El contenido de contador es -474743
# El contenido de contador es -474745
# El contenido de contador es -474747
# El contenido de contador es -474749
# El contenido de contador es -474751
# El contenido de contador es -474753
# El contenido de contador es -474755
# El contenido de contador es -474757
# El contenido de contador es -474759
# El contenido de contador es -474761
# El contenido de contador es -474763
# El contenido de contador es -474765
# El contenido de contador es -474767
# El contenido de contador es -474769
# El contenido de contador es -474771
# El contenido de contador es -474773
# El contenido de contador es -474775
# El contenido de contador es -474777
# El contenido de contador es -474779
# El contenido de contador es -474781
# El contenido de contador es -474783
# El contenido de contador es -474785
# El contenido de contador es -474787
# El contenido de contador es -474789
# El contenido de contador es -474791
# El contenido de contador es -474793
# El contenido de contador es -474795
# El contenido de contador es -474797
# El contenido de contador es -474799
# El contenido de contador es -474801
# El contenido de contador es -474803
# El contenido de contador es -474805
# El contenido de contador es -474807
# El contenido de contador es -474809
# El contenido de contador es -474811
# El contenido de contador es -474813
# El contenido de contador es -474815
# El contenido de contador es -474817
# El contenido de contador es -474819
# El contenido de contador es -474821
# El contenido de contador es -474823
# El contenido de contador es -474825
# El contenido de contador es -474827
# El contenido de contador es -474829
# El contenido de contador es -474831
# El contenido de contador es -474833
# El contenido de contador es -474835
# El contenido de contador es -474837
# El contenido de contador es -474839
# El contenido de contador es -474841
# El contenido de contador es -474843
# El contenido de contador es -474845
# El contenido de contador es -474847
# El contenido de contador es -474849
# El contenido de contador es -474851
# El contenido de contador es -474853
# El contenido de contador es -474855
# El contenido de contador es -474857
# El contenido de contador es -474859
# El contenido de contador es -474861
# El contenido de contador es -474863
# El contenido de contador es -474865
# El contenido de contador es -474867
# El contenido de contador es -474869
# El contenido de contador es -474871
# El contenido de contador es -474873
# El contenido de contador es -474875
# El contenido de contador es -474877
# El contenido de contador es -474879
# El contenido de contador es -474881
# El contenido de contador es -474883
# El contenido de contador es -474885
# El contenido de contador es -474887
# El contenido de contador es -474889
# El contenido de contador es -474891
# El contenido de contador es -474893
# El contenido de contador es -474895
# El contenido de contador es -474897
# El contenido de contador es -474899
# El contenido de contador es -474901
# El contenido de contador es -474903
# El contenido de contador es -474905
# El contenido de contador es -474907
# El contenido de contador es -474909
# El contenido de contador es -474911
# El contenido de contador es -474913
# El contenido de contador es -474915
# El contenido de contador es -474917
# El contenido de contador es -474919
# El contenido de contador es -474921
# El contenido de contador es -474923
# El contenido de contador es -474925
# El contenido de contador es -474927
# El contenido de contador es -474929
# El contenido de contador es -474931
# El contenido de contador es -474933
# El contenido de contador es -474935
# El contenido de contador es -474937
# El contenido de contador es -474939
# El contenido de contador es -474941
# El contenido de contador es -474943
# El contenido de contador es -474945
# El contenido de contador es -474947
# El contenido de contador es -474949
# El contenido de contador es -474951
# El contenido de contador es -474953
# El contenido de contador es -474955
# El contenido de contador es -474957
# El contenido de contador es -474959
# El contenido de contador es -474961
# El contenido de contador es -474963
# El contenido de contador es -474965
# El contenido de contador es -474967
# El contenido de contador es -474969
# El contenido de contador es -474971
# El contenido de contador es -474973
# El contenido de contador es -474975
# El contenido de contador es -474977
# El contenido de contador es -474979
# El contenido de contador es -474981
# El contenido de contador es -474983
# El contenido de contador es -474985
# El contenido de contador es -474987
# El contenido de contador es -474989
# El contenido de contador es -474991
# El contenido de contador es -474993
# El contenido de contador es -474995
# El contenido de contador es -474997
# El contenido de contador es -474999
# El contenido de contador es -475001
# El contenido de contador es -475003
# El contenido de contador es -475005
# El contenido de contador es -475007
# El contenido de contador es -475009
# El contenido de contador es -475011
# El contenido de contador es -475013
# El contenido de contador es -475015
# El contenido de contador es -475017
# El contenido de contador es -475019
# El contenido de contador es -475021
# El contenido de contador es -475023
# El contenido de contador es -475025
# El contenido de contador es -475027
# El contenido de contador es -475029
# El contenido de contador es -475031
# El contenido de contador es -475033
# El contenido de contador es -475035
# El contenido de contador es -475037
# El contenido de contador es -475039
# El contenido de contador es -475041
# El contenido de contador es -475043
# El contenido de contador es -475045
# El contenido de contador es -475047
# El contenido de contador es -475049
# El contenido de contador es -475051
# El contenido de contador es -475053
# El contenido de contador es -475055
# El contenido de contador es -475057
# El contenido de contador es -475059
# El contenido de contador es -475061
# El contenido de contador es -475063
# El contenido de contador es -475065
# El contenido de contador es -475067
# El contenido de contador es -475069
# El contenido de contador es -475071
# El contenido de contador es -475073
# El contenido de contador es -475075
# El contenido de contador es -475077
# El contenido de contador es -475079
# El contenido de contador es -475081
# El contenido de contador es -475083
# El contenido de contador es -475085
# El contenido de contador es -475087
# El contenido de contador es -475089
# El contenido de contador es -475091
# El contenido de contador es -475093
# El contenido de contador es -475095
# El contenido de contador es -475097
# El contenido de contador es -475099
# El contenido de contador es -475101
# El contenido de contador es -475103
# El contenido de contador es -475105
# El contenido de contador es -475107
# El contenido de contador es -475109
# El contenido de contador es -475111
# El contenido de contador es -475113
# El contenido de contador es -475115
# El contenido de contador es -475117
# El contenido de contador es -475119
# El contenido de contador es -475121
# El contenido de contador es -475123
# El contenido de contador es -475125
# El contenido de contador es -475127
# El contenido de contador es -475129
# El contenido de contador es -475131
# El contenido de contador es -475133
# El contenido de contador es -475135
# El contenido de contador es -475137
# El contenido de contador es -475139
# El contenido de contador es -475141
# El contenido de contador es -475143
# El contenido de contador es -475145
# El contenido de contador es -475147
# El contenido de contador es -475149
# El contenido de contador es -475151
# El contenido de contador es -475153
# El contenido de contador es -475155
# El contenido de contador es -475157
# El contenido de contador es -475159
# El contenido de contador es -475161
# El contenido de contador es -475163
# El contenido de contador es -475165
# El contenido de contador es -475167
# El contenido de contador es -475169
# El contenido de contador es -475171
# El contenido de contador es -475173
# El contenido de contador es -475175
# El contenido de contador es -475177
# El contenido de contador es -475179
# El contenido de contador es -475181
# El contenido de contador es -475183
# El contenido de contador es -475185
# El contenido de contador es -475187
# El contenido de contador es -475189
# El contenido de contador es -475191
# El contenido de contador es -475193
# El contenido de contador es -475195
# El contenido de contador es -475197
# El contenido de contador es -475199
# El contenido de contador es -475201
# El contenido de contador es -475203
# El contenido de contador es -475205
# El contenido de contador es -475207
# El contenido de contador es -475209
# El contenido de contador es -475211
# El contenido de contador es -475213
# El contenido de contador es -475215
# El contenido de contador es -475217
# El contenido de contador es -475219
# El contenido de contador es -475221
# El contenido de contador es -475223
# El contenido de contador es -475225
# El contenido de contador es -475227
# El contenido de contador es -475229
# El contenido de contador es -475231
# El contenido de contador es -475233
# El contenido de contador es -475235
# El contenido de contador es -475237
# El contenido de contador es -475239
# El contenido de contador es -475241
# El contenido de contador es -475243
# El contenido de contador es -475245
# El contenido de contador es -475247
# El contenido de contador es -475249
# El contenido de contador es -475251
# El contenido de contador es -475253
# El contenido de contador es -475255
# El contenido de contador es -475257
# El contenido de contador es -475259
# El contenido de contador es -475261
# El contenido de contador es -475263
# El contenido de contador es -475265
# El contenido de contador es -475267
# El contenido de contador es -475269
# El contenido de contador es -475271
# El contenido de contador es -475273
# El contenido de contador es -475275
# El contenido de contador es -475277
# El contenido de contador es -475279
# El contenido de contador es -475281
# El contenido de contador es -475283
# El contenido de contador es -475285
# El contenido de contador es -475287
# El contenido de contador es -475289
# El contenido de contador es -475291
# El contenido de contador es -475293
# El contenido de contador es -475295
# El contenido de contador es -475297
# El contenido de contador es -475299
# El contenido de contador es -475301
# El contenido de contador es -475303
# El contenido de contador es -475305
# El contenido de contador es -475307
# El contenido de contador es -475309
# El contenido de contador es -475311
# El contenido de contador es -475313
# El contenido de contador es -475315
# El contenido de contador es -475317
# El contenido de contador es -475319
# El contenido de contador es -475321
# El contenido de contador es -475323
# El contenido de contador es -475325
# El contenido de contador es -475327
# El contenido de contador es -475329
# El contenido de contador es -475331
# El contenido de contador es -475333
# El contenido de contador es -475335
# El contenido de contador es -475337
# El contenido de contador es -475339
# El contenido de contador es -475341
# El contenido de contador es -475343
# El contenido de contador es -475345
# El contenido de contador es -475347
# El contenido de contador es -475349
# El contenido de contador es -475351
# El contenido de contador es -475353
# El contenido de contador es -475355
# El contenido de contador es -475357
# El contenido de contador es -475359
# El contenido de contador es -475361
# El contenido de contador es -475363
# El contenido de contador es -475365
# El contenido de contador es -475367
# El contenido de contador es -475369
# El contenido de contador es -475371
# El contenido de contador es -475373
# El contenido de contador es -475375
# El contenido de contador es -475377
# El contenido de contador es -475379
# El contenido de contador es -475381
# El contenido de contador es -475383
# El contenido de contador es -475385
# El contenido de contador es -475387
# El contenido de contador es -475389
# El contenido de contador es -475391
# El contenido de contador es -475393
# El contenido de contador es -475395
# El contenido de contador es -475397
# El contenido de contador es -475399
# El contenido de contador es -475401
# El contenido de contador es -475403
# El contenido de contador es -475405
# El contenido de contador es -475407
# El contenido de contador es -475409
# El contenido de contador es -475411
# El contenido de contador es -475413
# El contenido de contador es -475415
# El contenido de contador es -475417
# El contenido de contador es -475419
# El contenido de contador es -475421
# El contenido de contador es -475423
# El contenido de contador es -475425
# El contenido de contador es -475427
# El contenido de contador es -475429
# El contenido de contador es -475431
# El contenido de contador es -475433
# El contenido de contador es -475435
# El contenido de contador es -475437
# El contenido de contador es -475439
# ...
# El contenido de contador es -481891
# El contenido de contador es -481893
# El contenido de contador es -481895
# El contenido de contador es -481897
# El contenido de contador es -481899
# El contenido de contador es -481901
# El contenido de contador es -481903
# El contenido de contador es -481905
# El contenido de contador es -481907
# El contenido de contador es -481909
# El contenido de contador es -481911
# El contenido de contador es -481913
# El contenido de contador es -481915
# El contenido de contador es -481917
# El contenido de contador es -481919
# El contenido de contador es -481921
# El contenido de contador es -481923
# El contenido de contador es -481925
# El contenido de contador es -481927
# El contenido de contador es -481929
# El contenido de contador es -481931
# El contenido de contador es -481933
# El contenido de contador es -481935
# El contenido de contador es -481937
# El contenido de contador es -481939
# El contenido de contador es -481941
# El contenido de contador es -481943
# El contenido de contador es -481945
# El contenido de contador es -481947
# El contenido de contador es -481949
# El contenido de contador es -481951
# El contenido de contador es -481953
# El contenido de contador es -481955
# El contenido de contador es -481957
# El contenido de contador es -481959
# El contenido de contador es -481961
# El contenido de contador es -481963
# El contenido de contador es -481965
# El contenido de contador es -481967
# El contenido de contador es -481969
# El contenido de contador es -481971
# El contenido de contador es -481973
# El contenido de contador es -481975
# El contenido de contador es -481977
# El contenido de contador es -481979
# El contenido de contador es -481981
# El contenido de contador es -481983
# El contenido de contador es -481985
# El contenido de contador es -481987
# El contenido de contador es -481989
# El contenido de contador es -481991
# El contenido de contador es -481993
# El contenido de contador es -481995
# El contenido de contador es -481997
# El contenido de contador es -481999
# El contenido de contador es -482001
# El contenido de contador es -482003
# El contenido de contador es -482005
# El contenido de contador es -482007
# El contenido de contador es -482009
# El contenido de contador es -482011
# El contenido de contador es -482013
# El contenido de contador es -482015
# El contenido de contador es -482017
# El contenido de contador es -482019
# El contenido de contador es -482021
# El contenido de contador es -482023
# El contenido de contador es -482025
# El contenido de contador es -482027
# El contenido de contador es -482029
# El contenido de contador es -482031
# El contenido de contador es -482033
# El contenido de contador es -482035
# El contenido de contador es -482037
# El contenido de contador es -482039
# El contenido de contador es -482041
# El contenido de contador es -482043
# El contenido de contador es -482045
# El contenido de contador es -482047
# El contenido de contador es -482049
# El contenido de contador es -482051
# El contenido de contador es -482053
# El contenido de contador es -482055
# El contenido de contador es -482057
# El contenido de contador es -482059
# El contenido de contador es -482061
# El contenido de contador es -482063
# El contenido de contador es -482065
# El contenido de contador es -482067
# El contenido de contador es -482069
# El contenido de contador es -482071
# El contenido de contador es -482073
# El contenido de contador es -482075
# El contenido de contador es -482077
# El contenido de contador es -482079
# El contenido de contador es -482081
# El contenido de contador es -482083
# El contenido de contador es -482085
# El contenido de contador es -482087
# El contenido de contador es -482089
# El contenido de contador es -482091
# El contenido de contador es -482093
# El contenido de contador es -482095
# El contenido de contador es -482097
# El contenido de contador es -482099
# El contenido de contador es -482101
# El contenido de contador es -482103
# El contenido de contador es -482105
# El contenido de contador es -482107
# El contenido de contador es -482109
# El contenido de contador es -482111
# El contenido de contador es -482113
# El contenido de contador es -482115
# El contenido de contador es -482117
# El contenido de contador es -482119
# El contenido de contador es -482121
# El contenido de contador es -482123
# El contenido de contador es -482125
# El contenido de contador es -482127
# El contenido de contador es -482129
# El contenido de contador es -482131
# El contenido de contador es -482133
# El contenido de contador es -482135
# El contenido de contador es -482137
# El contenido de contador es -482139
# El contenido de contador es -482141
# El contenido de contador es -482143
# El contenido de contador es -482145
# El contenido de contador es -482147
# El contenido de contador es -482149
# El contenido de contador es -482151
# El contenido de contador es -482153
# El contenido de contador es -482155
# El contenido de contador es -482157
# El contenido de contador es -482159
# El contenido de contador es -482161
# El contenido de contador es -482163
# El contenido de contador es -482165
# El contenido de contador es -482167
# El contenido de contador es -482169
# El contenido de contador es -482171
# El contenido de contador es -482173
# El contenido de contador es -482175
# El contenido de contador es -482177
# El contenido de contador es -482179
# El contenido de contador es -482181
# El contenido de contador es -482183
# El contenido de contador es -482185
# El contenido de contador es -482187
# El contenido de contador es -482189
# El contenido de contador es -482191
# El contenido de contador es -482193
# El contenido de contador es -482195
# El contenido de contador es -482197
# El contenido de contador es -482199
# El contenido de contador es -482201
# El contenido de contador es -482203
# El contenido de contador es -482205
# El contenido de contador es -482207
# El contenido de contador es -482209
# El contenido de contador es -482211
# El contenido de contador es -482213
# El contenido de contador es -482215
# El contenido de contador es -482217
# El contenido de contador es -482219
# El contenido de contador es -482221
# El contenido de contador es -482223
# El contenido de contador es -482225
# El contenido de contador es -482227
# El contenido de contador es -482229
# El contenido de contador es -482231
# El contenido de contador es -482233
# El contenido de contador es -482235
# El contenido de contador es -482237
# El contenido de contador es -482239
# El contenido de contador es -482241
# El contenido de contador es -482243
# El contenido de contador es -482245
# El contenido de contador es -482247
# El contenido de contador es -482249
# El contenido de contador es -482251
# El contenido de contador es -482253
# El contenido de contador es -482255
# El contenido de contador es -482257
# El contenido de contador es -482259
# El contenido de contador es -482261
# El contenido de contador es -482263
# El contenido de contador es -482265
# El contenido de contador es -482267
# El contenido de contador es -482269
# El contenido de contador es -482271
# El contenido de contador es -482273
# El contenido de contador es -482275
# El contenido de contador es -482277
# El contenido de contador es -482279
# El contenido de contador es -482281
# El contenido de contador es -482283
# El contenido de contador es -482285
# El contenido de contador es -482287
# El contenido de contador es -482289
# El contenido de contador es -482291
# El contenido de contador es -482293
# El contenido de contador es -482295
# El contenido de contador es -482297
# El contenido de contador es -482299
# El contenido de contador es -482301
# El contenido de contador es -482303
# El contenido de contador es -482305
# El contenido de contador es -482307
# El contenido de contador es -482309
# El contenido de contador es -482311
# El contenido de contador es -482313
# El contenido de contador es -482315
# El contenido de contador es -482317
# El contenido de contador es -482319
# El contenido de contador es -482321
# El contenido de contador es -482323
# El contenido de contador es -482325
# El contenido de contador es -482327
# El contenido de contador es -482329
# El contenido de contador es -482331
# El contenido de contador es -482333
# El contenido de contador es -482335
# El contenido de contador es -482337
# El contenido de contador es -482339
# El contenido de contador es -482341
# El contenido de contador es -482343
# El contenido de contador es -482345
# El contenido de contador es -482347
# El contenido de contador es -482349
# El contenido de contador es -482351
# El contenido de contador es -482353
# El contenido de contador es -482355
# El contenido de contador es -482357
# El contenido de contador es -482359
# El contenido de contador es -482361
# El contenido de contador es -482363
# El contenido de contador es -482365
# El contenido de contador es -482367
# El contenido de contador es -482369
# El contenido de contador es -482371
# El contenido de contador es -482373
# El contenido de contador es -482375
# El contenido de contador es -482377
# El contenido de contador es -482379
# El contenido de contador es -482381
# El contenido de contador es -482383
# El contenido de contador es -482385
# El contenido de contador es -482387
# El contenido de contador es -482389
# El contenido de contador es -482391
# El contenido de contador es -482393
# El contenido de contador es -482395
# El contenido de contador es -482397
# El contenido de contador es -482399
# El contenido de contador es -482401
# El contenido de contador es -482403
# El contenido de contador es -482405
# El contenido de contador es -482407
# El contenido de contador es -482409
# El contenido de contador es -482411
# El contenido de contador es -482413
# El contenido de contador es -482415
# El contenido de contador es -482417
# El contenido de contador es -482419
# El contenido de contador es -482421
# El contenido de contador es -482423
# El contenido de contador es -482425
# El contenido de contador es -482427
# El contenido de contador es -482429
# El contenido de contador es -482431
# El contenido de contador es -482433
# El contenido de contador es -482435
# El contenido de contador es -482437
# El contenido de contador es -482439
# El contenido de contador es -482441
# El contenido de contador es -482443
# El contenido de contador es -482445
# El contenido de contador es -482447
# El contenido de contador es -482449
# El contenido de contador es -482451
# El contenido de contador es -482453
# El contenido de contador es -482455
# El contenido de contador es -482457
# El contenido de contador es -482459
# El contenido de contador es -482461
# El contenido de contador es -482463
# El contenido de contador es -482465
# El contenido de contador es -482467
# El contenido de contador es -482469
# El contenido de contador es -482471
# El contenido de contador es -482473
# El contenido de contador es -482475
# El contenido de contador es -482477
# El contenido de contador es -482479
# El contenido de contador es -482481
# El contenido de contador es -482483
# El contenido de contador es -482485
# El contenido de contador es -482487
# El contenido de contador es -482489
# El contenido de contador es -482491
# El contenido de contador es -482493
# El contenido de contador es -482495
# El contenido de contador es -482497
# El contenido de contador es -482499
# El contenido de contador es -482501
# El contenido de contador es -482503
# El contenido de contador es -482505
# El contenido de contador es -482507
# El contenido de contador es -482509
# El contenido de contador es -482511
# El contenido de contador es -482513
# El contenido de contador es -482515
# El contenido de contador es -482517
# El contenido de contador es -482519
# El contenido de contador es -482521
# El contenido de contador es -482523
# El contenido de contador es -482525
# El contenido de contador es -482527
# El contenido de contador es -482529
# El contenido de contador es -482531
# El contenido de contador es -482533
# El contenido de contador es -482535
# El contenido de contador es -482537
# El contenido de contador es -482539
# El contenido de contador es -482541
# El contenido de contador es -482543
# El contenido de contador es -482545
# El contenido de contador es -482547
# El contenido de contador es -482549
# El contenido de contador es -482551
# El contenido de contador es -482553
# El contenido de contador es -482555
# El contenido de contador es -482557
# El contenido de contador es -482559
# El contenido de contador es -482561
# El contenido de contador es -482563
# El contenido de contador es -482565
# El contenido de contador es -482567
# El contenido de contador es -482569
# El contenido de contador es -482571
# El contenido de contador es -482573
# El contenido de contador es -482575
# El contenido de contador es -482577
# El contenido de contador es -482579
# El contenido de contador es -482581
# El contenido de contador es -482583
# El contenido de contador es -482585
# El contenido de contador es -482587
# El contenido de contador es -482589
# El contenido de contador es -482591
# El contenido de contador es -482593
# El contenido de contador es -482595
# El contenido de contador es -482597
# El contenido de contador es -482599
# El contenido de contador es -482601
# El contenido de contador es -482603
# El contenido de contador es -482605
# El contenido de contador es -482607
# El contenido de contador es -482609
# El contenido de contador es -482611
# El contenido de contador es -482613
# El contenido de contador es -482615
# El contenido de contador es -482617
# El contenido de contador es -482619
# El contenido de contador es -482621
# El contenido de contador es -482623
# El contenido de contador es -482625
# El contenido de contador es -482627
# El contenido de contador es -482629
# El contenido de contador es -482631
# El contenido de contador es -482633
# El contenido de contador es -482635
# El contenido de contador es -482637
# El contenido de contador es -482639
# El contenido de contador es -482641
# El contenido de contador es -482643
# El contenido de contador es -482645
# El contenido de contador es -482647
# El contenido de contador es -482649
# El contenido de contador es -482651
# El contenido de contador es -482653
# El contenido de contador es -482655
# El contenido de contador es -482657
# El contenido de contador es -482659
# El contenido de contador es -482661
# El contenido de contador es -482663
# El contenido de contador es -482665
# El contenido de contador es -482667
# El contenido de contador es -482669
# El contenido de contador es -482671
# El contenido de contador es -482673
# El contenido de contador es -482675
# El contenido de contador es -482677
# El contenido de contador es -482679
# El contenido de contador es -482681
# El contenido de contador es -482683
# El contenido de contador es -482685
# El contenido de contador es -482687
# El contenido de contador es -482689
# El contenido de contador es -482691
# El contenido de contador es -482693
# El contenido de contador es -482695
# El contenido de contador es -482697
# El contenido de contador es -482699
# El contenido de contador es -482701
# El contenido de contador es -482703
# El contenido de contador es -482705
# El contenido de contador es -482707
# El contenido de contador es -482709
# El contenido de contador es -482711
# El contenido de contador es -482713
# El contenido de contador es -482715
# El contenido de contador es -482717
# El contenido de contador es -482719
# El contenido de contador es -482721
# El contenido de contador es -482723
# El contenido de contador es -482725
# El contenido de contador es -482727
# El contenido de contador es -482729
# El contenido de contador es -482731
# El contenido de contador es -482733
# El contenido de contador es -482735
# El contenido de contador es -482737
# El contenido de contador es -482739
# El contenido de contador es -482741
# El contenido de contador es -482743
# El contenido de contador es -482745
# El contenido de contador es -482747
# El contenido de contador es -482749
# El contenido de contador es -482751
# El contenido de contador es -482753
# El contenido de contador es -482755
# El contenido de contador es -482757
# El contenido de contador es -482759
# El contenido de contador es -482761
# El contenido de contador es -482763
# El contenido de contador es -482765
# El contenido de contador es -482767
# El contenido de contador es -482769
# El contenido de contador es -482771
# El contenido de contador es -482773
# El contenido de contador es -482775
# KeyboardInterrupt

# %%
contador = 3
while contador > 0:
  contador = contador - 1
  print("El contenido de contador es", contador)
  # al colocar el > se soluciona ese problema
# Out:
# El contenido de contador es 2
# El contenido de contador es 1
# El contenido de contador es 0

# %%
# sentencia for
for iterador in [1, 2, 3]:
  print(iterador)
# Out:
# 1
# 2
# 3

# %%
lista = list((2, 1, 0))
tupla = tuple((2, 1, 0))
conjunto = set((2, 1, 0))
diccionario = dict(((2,"Dos"), (1, "Uno"), (0, "Cero")))

for iterador in lista:
  print(iterador)

for iterador in tupla:
  print(iterador)

for iterador in conjunto:
  print(iterador)

for iterador in diccionario:
  print(iterador)

for iterador in diccionario.values():
  print(iterador)

for iterador in diccionario.items():
  print(iterador)
# Out:
# 2
# 1
# 0
# 2
# 1
# 0
# 0
# 1
# 2
# 2
# 1
# 0
# Dos
# Uno
# Cero
# (2, 'Dos')
# (1, 'Uno')
# (0, 'Cero')

# %%
lista = ["Vamos", "a", "acceder", "a", "esta", "lista", "por", "índices"]

for indice in range(len(lista)):
  print("Indice:", indice,"Elemento:", lista[indice])
# Out:
# Indice: 0 Elemento: Vamos
# Indice: 1 Elemento: a
# Indice: 2 Elemento: acceder
# Indice: 3 Elemento: a
# Indice: 4 Elemento: esta
# Indice: 5 Elemento: lista
# Indice: 6 Elemento: por
# Indice: 7 Elemento: índices

# %%
for numero in range(5):
  print(numero)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for numero in range(5):
  if numero == 3:
    break
  print(numero)
# Out:
# 0
# 1
# 2

# %%
for numero in range(5):
  if numero == 3:
    continue
  print(numero)
# Out:
# 0
# 1
# 2
# 4

# %%
intentos = 3
while intentos > 0:
  if input(">>> Escriba la contraseña:") == "BitBoss":
    print("¡Correcta!")
    break
  intentos = intentos - 1
  print("Contraseña incorrecta")
# Out:
# >>> Escriba la contraseña:jhdjd
# Contraseña incorrecta
# >>> Escriba la contraseña:kjsdus
# Contraseña incorrecta
# >>> Escriba la contraseña:hola
# Contraseña incorrecta

# %%
intentos = 3
while intentos > 0:
  if input(">>> Escriba la contraseña:") == "BitBoss":
    print("¡Correcta!")
    break
  intentos = intentos - 1
  print("Contraseña incorrecta")
else:
  print("Se te acabaron los intentos :(")
# Out:
# >>> Escriba la contraseña:hola
# Contraseña incorrecta
# >>> Escriba la contraseña:hpla
# Contraseña incorrecta
# >>> Escriba la contraseña:hola
# Contraseña incorrecta
# Se te acabaron los intentos :(
