# %% [markdown]
# <a href="https://colab.research.google.com/github/joseydyrueda-code/programacion1/blob/main/tarea.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lista = ['j','o','s','s']
print(lista)
tupla = tuple(lista)
print(tupla)
diccionario = dict(enumerate(lista))
print(diccionario)
conjunto = set(lista)
print(conjunto)
# Out:
# ['j', 'o', 's', 's']
# ('j', 'o', 's', 's')
# {0: 'j', 1: 'o', 2: 's', 3: 's'}
# {'o', 'j', 's'}

# %%
tupla = ('j','o','s','s')
print(tupla)
lista = list(tupla)
print(lista)
diccionario = dict(enumerate(tupla))
print(diccionario)
conjunto = set(tupla)
print(conjunto)
# Out:
# ('j', 'o', 's', 's')
# ['j', 'o', 's', 's']
# {0: 'j', 1: 'o', 2: 's', 3: 's'}
# {'o', 'j', 's'}

# %%
conjunto = {'j','o','s','s'}
print(conjunto)
lista = list(conjunto)
print(lista)
tupla = tuple(conjunto)
print(tupla)
diccionario = dict(enumerate(conjunto))
print(diccionario)
# Out:
# {'o', 'j', 's'}
# ['o', 'j', 's']
# ('o', 'j', 's')
# {0: 'o', 1: 'j', 2: 's'}

# %%
diccionario = {'j':0,'o':1,'s':2,'s':3}
print(diccionario)
lista = list(diccionario)
print(lista)
tupla = tuple(diccionario)
print(tupla)
conjunto = set(diccionario)
print(conjunto)
# Out:
# {'j': 0, 'o': 1, 's': 3}
# ['j', 'o', 's']
# ('j', 'o', 's')
# {'o', 'j', 's'}
